# %% [markdown]
# # 2026/04/23 Computational AI and thinkung_TA04_Python(1)
# TA: Chian-Yu, Ye
#
# 1. After receiving the file, please go to File > Make a copy in Google Drive to save it to your own Drive before making any edits.
# 2. Completing the basic exercises earns 2 points. There are three homework questions, each worth 1 point.

# %% [markdown]
# # Homework
# - Please label each question number clearly.
# - After completing all code, run every cell and export the notebook as .ipynb (File > Download > Download .ipynb).
# - Before submission, rename the file to your group name.
#
# ### HW bonus
# - You can earn 1 bonus point by finishing bonus task
# - Please label each question number clearly.
# - After completing all code, run every cell and export the notebook as .ipynb(File > Download > Download .ipynb).
#
# ---
#
# Q1. Ask the user to enter a string, then print that string 100 times, separated by a space.
# For example, if the user enters hi, the output should be:
# hi hi hi hi hi hi hi ... (a total of 100 times)
#
# Q2. Write a program to test whether a string is a palindrome,
# which means the reversed string is the same as the original one.
# Example: rester
# ```python
# palindrome_input = input('input sting')
# if _____________________________:
#     print("This string is a palindrome")
# else:
#     print("This string is not a palindrome")
# ```
#
# 3. Given the sorted sequence [1,12,14,21,23,36,43,48,56,78,89,102,126,147,168,171,199,222,256,348], find the median (use len to calculate, do not directly substitute the number).

# %%
# Q1
user_input = input("Enter a string: ")
result = " ".join([user_input] * 100)
print(result)
# Out:
# Enter a string: hi
# hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi hi

# %%
# Q2
palindrome_input = input("input string: ")

if palindrome_input == palindrome_input[::-1]:
    print("This string is a palindrome")
else:
    print("This string is not a palindrome")
# Out:
# input string: 181
# This string is a palindrome

# %%
# Q3
data = [1,12,14,21,23,36,43,48,56,78,89,102,126,147,168,171,199,222,256,348]

n = len(data)

if n % 2 == 1:
    median = data[n // 2]
else:
    median = (data[n // 2 - 1] + data[n // 2]) / 2

print("Median:", median)
# Out:
# Median: 83.5
